# %%
import pandas as pd
import pyarrow
import os

# %%
os.chdir("D:/TUSZ_DataLake")
os.getcwd()
# Out:
# 'D:\\TUSZ_DataLake'

# %%
ruta = "02_Metadata/metadata_patients.parquet"
df_patients = pd.read_parquet(ruta, engine="pyarrow")

# %%
df_patients
# Out:
#      patient_num_id patient_id original_split  age  gender  n_sessions  \
# 0                 1   aaaaalpj          train   55       2           4
# 1                 2   aaaaaipg          train   38       2           3
# 2                 3   aaaaatvk           eval   28       2           3
# 3                 4   aaaaapkv          train   89       2           1
# 4                 5   aaaaalaw          train   28       2           1
# ..              ...        ...            ...  ...     ...         ...
# 670             671   aaaaabom          train   29       2           1
# 671             672   aaaaacpl          train   20       2           1
# 672             673   aaaaahsn          train   47       1           1
# 673             674   aaaaamqq          train   21       1           2
# 674             675   aaaaaclp          train   76       2           5
#
#      total_duration_sec  split_final
# 0                3015.0            0
# 1                4600.0            0
# ...

# %%
ruta = "04_TUSZ_Features_ML/version=v1_raw_labels/1/session_s002_2011.parquet"
df = pd.read_parquet(ruta, engine="pyarrow")

# %%
df["label"].unique()
# Out:
# array(['bckg', 'fnsz'], dtype=object)
